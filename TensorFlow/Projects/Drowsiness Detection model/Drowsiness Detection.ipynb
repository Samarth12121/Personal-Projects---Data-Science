# %%
import numpy as np
import cv2
from tensorflow.keras.layers import Input, Conv2D,BatchNormalization, Dropout, Flatten, Dense, MaxPool2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.optimizers import Adam, SGD
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
from tensorflow.keras.regularizers import l2
import tensorflow as tf
import pandas as pd
from imutils.face_utils import FaceAligner
from imutils.face_utils import rect_to_bb
import imutils

# %%
data = np.load(r"C:\Users\dell\Downloads\driver_drowsiness_detection_modified\driver_drowsiness_detection\dataset_compressed.npz", allow_pickle=True)
X = data['arr_0']
Y = data['arr_1']

X = list(X)
Y = list(Y)
print(len(X))
print(len(Y))
# Out:
# 1452
# 1452

# %%
for i in range(len(X)):
    img = X[i]
    img = cv2.resize(img, (32, 32))
    X[i] = img
    
print(len(X))
print(X[0].shape)
# Out:
# 1452
# (32, 32, 3)

# %%
label_encoder = LabelEncoder()
Y = label_encoder.fit_transform(Y)
print(Y.shape)
print(Y[0])
print(set(Y))
# Out:
# (1452,)
# 0
# {0, 1}

# %%
X = np.array(X)
Y = np.array(Y)
print(X.shape)
print(Y.shape)
# Out:
# (1452, 32, 32, 3)
# (1452,)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)

Y_train = to_categorical(Y_train)
Y_test = to_categorical(Y_test)

print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (1161, 32, 32, 3)
# (1161,)
# (291, 32, 32, 3)
# (291,)
# (1161, 32, 32, 3)
# (1161, 2)
# (291, 32, 32, 3)
# (291, 2)

# %%
figure1 = plt.figure(figsize=(5, 5))
idx_closed = np.where(Y==0)
img_closed = X[idx_closed[0][0]]
plt.imshow(img_closed)
plt.title('Image of Closed Eye representing Driver is sleeping')
plt.axis('off')
plt.show()

figure2 = plt.figure(figsize=(5, 5))
idx_open = np.where(Y==1)
img_open = X[idx_open[0][0]]
plt.imshow(img_open)
plt.title('Image of Open Eye representing Driver is not sleeping')
plt.axis('off')
plt.show()

# %%
def driver_drowsiness_detection_model(input_shape=(32, 32, 3)):
    model = Sequential()
    model.add(Input(shape=input_shape))
    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv1', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv2', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv3', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv4', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv5', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv6', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), padding='same', strides=(1, 1), name='conv7', activation='relu', 
                     kernel_initializer=glorot_uniform(seed=0)))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))
    model.add(MaxPool2D((2, 2), strides=(2, 2)))
    
    
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer=glorot_uniform(seed=0), name='fc1'))
    model.add(Dropout(0.5))
    model.add(Dense(128, activation='relu', kernel_initializer=glorot_uniform(seed=0), name='fc2'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax', kernel_initializer=glorot_uniform(seed=0), name='fc3'))
    
    optimizer = Adam(0.0001)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
model= driver_drowsiness_detection_model(input_shape=(32, 32, 3))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1 (Conv2D)                  │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2 (Conv2D)                  │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3 (Conv2D)                  │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv4 (Conv2D)                  │ (None, 8, 8, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 8, 8, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv5 (Conv2D)                  │ (None, 4, 4, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 4, 4, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv6 (Conv2D)                  │ (None, 4, 4, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 4, 4, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv7 (Conv2D)                  │ (None, 4, 4, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 4, 4, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 2, 2, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc1 (Dense)                     │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc2 (Dense)                     │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc3 (Dense)                     │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 227,554 (888.88 KB)
#  Trainable params: 226,786 (885.88 KB)
#  Non-trainable params: 768 (3.00 KB)

# %%
aug = ImageDataGenerator(rotation_range=20, zoom_range=0.2, horizontal_flip=True)
hist = model.fit(aug.flow(X_train, Y_train, batch_size=128), batch_size=128, epochs=200, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/200
# C:\Users\dell\Desktop\Personal Projects - Application of Data Science\Personal-Projects---Data-Science\TensorFlow\Projects\.venv\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 367ms/step - accuracy: 0.5384 - loss: 1.3204 - val_accuracy: 0.4605 - val_loss: 0.7107
# Epoch 2/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 267ms/step - accuracy: 0.5539 - loss: 1.3651 - val_accuracy: 0.4536 - val_loss: 0.7172
# Epoch 3/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 453ms/step - accuracy: 0.5518 - loss: 1.0470 - val_accuracy: 0.4914 - val_loss: 0.6984
# Epoch 4/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 291ms/step - accuracy: 0.5763 - loss: 0.9816 - val_accuracy: 0.5258 - val_loss: 0.6676
# Epoch 5/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 254ms/step - accuracy: 0.5918 - loss: 0.9619 - val_accuracy: 0.6082 - val_loss: 0.6432
# Epoch 6/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 241ms/step - accuracy: 0.6036 - loss: 1.0189 - val_accuracy: 0.7079 - val_loss: 0.6277
# Epoch 7/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 238ms/step - accuracy: 0.6151 - loss: 0.7798 - val_accuracy: 0.7320 - val_loss: 0.6180
# Epoch 8/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 238ms/step - accuracy: 0.6626 - loss: 0.7618 - val_accuracy: 0.7423 - val_loss: 0.6107
# Epoch 9/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 237ms/step - accuracy: 0.6286 - loss: 0.7656 - val_accuracy: 0.7354 - val_loss: 0.6045
# Epoch 10/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 242ms/step - accuracy: 0.6616 - loss: 0.6510 - val_accuracy: 0.7423 - val_loss: 0.5954
# Epoch 11/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 290ms/step - accuracy: 0.6346 - loss: 0.7473 - val_accuracy: 0.7491 - val_loss: 0.5838
# Epoch 12/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 296ms/step - accuracy: 0.6341 - loss: 0.7205 - val_accuracy: 0.7526 - val_loss: 0.5721
# Epoch 13/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 257ms/step - accuracy: 0.6555 - loss: 0.6577 - val_accuracy: 0.7595 - val_loss: 0.5606
# Epoch 14/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 251ms/step - accuracy: 0.6809 - loss: 0.6597 - val_accuracy: 0.7595 - val_loss: 0.5480
# Epoch 15/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 260ms/step - accuracy: 0.6867 - loss: 0.6318 - val_accuracy: 0.7766 - val_loss: 0.5352
# Epoch 16/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 267ms/step - accuracy: 0.6826 - loss: 0.6934 - val_accuracy: 0.7835 - val_loss: 0.5183
# Epoch 17/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 283ms/step - accuracy: 0.6959 - loss: 0.5841 - val_accuracy: 0.7938 - val_loss: 0.5025
# Epoch 18/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 310ms/step - accuracy: 0.6998 - loss: 0.5820 - val_accuracy: 0.8110 - val_loss: 0.4883
# Epoch 19/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 285ms/step - accuracy: 0.6757 - loss: 0.6767 - val_accuracy: 0.8351 - val_loss: 0.4734
# Epoch 20/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 350ms/step - accuracy: 0.7370 - loss: 0.5847 - val_accuracy: 0.8488 - val_loss: 0.4589
# Epoch 21/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 298ms/step - accuracy: 0.6989 - loss: 0.5672 - val_accuracy: 0.8557 - val_loss: 0.4446
# Epoch 22/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 263ms/step - accuracy: 0.7334 - loss: 0.6027 - val_accuracy: 0.8488 - val_loss: 0.4328
# Epoch 23/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 278ms/step - accuracy: 0.7332 - loss: 0.5684 - val_accuracy: 0.8557 - val_loss: 0.4190
# Epoch 24/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 527ms/step - accuracy: 0.7507 - loss: 0.5053 - val_accuracy: 0.8625 - val_loss: 0.4026
# Epoch 25/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 602ms/step - accuracy: 0.7470 - loss: 0.5266 - val_accuracy: 0.8660 - val_loss: 0.3867
# Epoch 26/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 332ms/step - accuracy: 0.7290 - loss: 0.5386 - val_accuracy: 0.8729 - val_loss: 0.3719
# Epoch 27/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 309ms/step - accuracy: 0.7690 - loss: 0.4564 - val_accuracy: 0.8729 - val_loss: 0.3568
# Epoch 28/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 302ms/step - accuracy: 0.7745 - loss: 0.5195 - val_accuracy: 0.8832 - val_loss: 0.3420
# Epoch 29/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 283ms/step - accuracy: 0.7783 - loss: 0.4789 - val_accuracy: 0.8866 - val_loss: 0.3295
# Epoch 30/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 287ms/step - accuracy: 0.7841 - loss: 0.4699 - val_accuracy: 0.8935 - val_loss: 0.3173
# Epoch 31/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 250ms/step - accuracy: 0.8072 - loss: 0.4598 - val_accuracy: 0.9003 - val_loss: 0.3072
# Epoch 32/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 266ms/step - accuracy: 0.7919 - loss: 0.4785 - val_accuracy: 0.8969 - val_loss: 0.2952
# Epoch 33/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 306ms/step - accuracy: 0.8161 - loss: 0.4514 - val_accuracy: 0.9141 - val_loss: 0.2787
# Epoch 34/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 281ms/step - accuracy: 0.8320 - loss: 0.4054 - val_accuracy: 0.9141 - val_loss: 0.2654
# Epoch 35/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 279ms/step - accuracy: 0.8330 - loss: 0.3596 - val_accuracy: 0.9072 - val_loss: 0.2532
# Epoch 36/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 271ms/step - accuracy: 0.8246 - loss: 0.3799 - val_accuracy: 0.9141 - val_loss: 0.2437
# Epoch 37/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.8376 - loss: 0.4004 - val_accuracy: 0.9141 - val_loss: 0.2318
# Epoch 38/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 262ms/step - accuracy: 0.8099 - loss: 0.4067 - val_accuracy: 0.9175 - val_loss: 0.2215
# Epoch 39/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 354ms/step - accuracy: 0.8434 - loss: 0.3639 - val_accuracy: 0.9244 - val_loss: 0.2139
# Epoch 40/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - accuracy: 0.8695 - loss: 0.3091 - val_accuracy: 0.9210 - val_loss: 0.2081
# Epoch 41/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 242ms/step - accuracy: 0.8626 - loss: 0.3252 - val_accuracy: 0.9244 - val_loss: 0.2015
# Epoch 42/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 238ms/step - accuracy: 0.8582 - loss: 0.3622 - val_accuracy: 0.9244 - val_loss: 0.1951
# Epoch 43/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 239ms/step - accuracy: 0.8824 - loss: 0.3237 - val_accuracy: 0.9313 - val_loss: 0.1853
# Epoch 44/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 242ms/step - accuracy: 0.8806 - loss: 0.3088 - val_accuracy: 0.9347 - val_loss: 0.1768
# Epoch 45/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 241ms/step - accuracy: 0.8853 - loss: 0.2760 - val_accuracy: 0.9347 - val_loss: 0.1719
# Epoch 46/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 233ms/step - accuracy: 0.8992 - loss: 0.2899 - val_accuracy: 0.9347 - val_loss: 0.1679
# Epoch 47/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 232ms/step - accuracy: 0.8615 - loss: 0.3163 - val_accuracy: 0.9381 - val_loss: 0.1627
# Epoch 48/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 244ms/step - accuracy: 0.8856 - loss: 0.2881 - val_accuracy: 0.9381 - val_loss: 0.1561
# Epoch 49/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 237ms/step - accuracy: 0.9071 - loss: 0.2470 - val_accuracy: 0.9347 - val_loss: 0.1493
# Epoch 50/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 235ms/step - accuracy: 0.9013 - loss: 0.2706 - val_accuracy: 0.9313 - val_loss: 0.1490
# Epoch 51/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 234ms/step - accuracy: 0.8925 - loss: 0.2556 - val_accuracy: 0.9313 - val_loss: 0.1497
# Epoch 52/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 237ms/step - accuracy: 0.9048 - loss: 0.2432 - val_accuracy: 0.9347 - val_loss: 0.1413
# Epoch 53/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 233ms/step - accuracy: 0.9089 - loss: 0.2163 - val_accuracy: 0.9347 - val_loss: 0.1387
# Epoch 54/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 238ms/step - accuracy: 0.9072 - loss: 0.2961 - val_accuracy: 0.9416 - val_loss: 0.1365
# Epoch 55/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 242ms/step - accuracy: 0.9017 - loss: 0.2526 - val_accuracy: 0.9416 - val_loss: 0.1351
# Epoch 56/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 235ms/step - accuracy: 0.9240 - loss: 0.2034 - val_accuracy: 0.9485 - val_loss: 0.1324
# Epoch 57/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 239ms/step - accuracy: 0.9192 - loss: 0.2181 - val_accuracy: 0.9485 - val_loss: 0.1295
# Epoch 58/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 244ms/step - accuracy: 0.9269 - loss: 0.2115 - val_accuracy: 0.9485 - val_loss: 0.1289
# Epoch 59/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 246ms/step - accuracy: 0.9351 - loss: 0.1966 - val_accuracy: 0.9416 - val_loss: 0.1178
# Epoch 60/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 247ms/step - accuracy: 0.9404 - loss: 0.1704 - val_accuracy: 0.9416 - val_loss: 0.1205
# Epoch 61/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 266ms/step - accuracy: 0.9248 - loss: 0.2187 - val_accuracy: 0.9416 - val_loss: 0.1210
# Epoch 62/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 235ms/step - accuracy: 0.9207 - loss: 0.2224 - val_accuracy: 0.9416 - val_loss: 0.1195
# Epoch 63/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 234ms/step - accuracy: 0.9006 - loss: 0.2385 - val_accuracy: 0.9450 - val_loss: 0.1094
# Epoch 64/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 245ms/step - accuracy: 0.9365 - loss: 0.2174 - val_accuracy: 0.9381 - val_loss: 0.1108
# Epoch 65/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 242ms/step - accuracy: 0.9235 - loss: 0.2140 - val_accuracy: 0.9450 - val_loss: 0.1216
# Epoch 66/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 236ms/step - accuracy: 0.9181 - loss: 0.1847 - val_accuracy: 0.9381 - val_loss: 0.1256
# Epoch 67/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 236ms/step - accuracy: 0.9367 - loss: 0.2408 - val_accuracy: 0.9485 - val_loss: 0.1138
# Epoch 68/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 239ms/step - accuracy: 0.9298 - loss: 0.1987 - val_accuracy: 0.9519 - val_loss: 0.1118
# Epoch 69/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 243ms/step - accuracy: 0.9289 - loss: 0.1690 - val_accuracy: 0.9485 - val_loss: 0.1157
# Epoch 70/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 261ms/step - accuracy: 0.9525 - loss: 0.1390 - val_accuracy: 0.9450 - val_loss: 0.1151
# Epoch 71/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 235ms/step - accuracy: 0.9375 - loss: 0.1562 - val_accuracy: 0.9416 - val_loss: 0.1147
# Epoch 72/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 239ms/step - accuracy: 0.9515 - loss: 0.1360 - val_accuracy: 0.9381 - val_loss: 0.1178
# Epoch 73/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 235ms/step - accuracy: 0.9138 - loss: 0.2304 - val_accuracy: 0.9416 - val_loss: 0.1125
# Epoch 74/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 234ms/step - accuracy: 0.9511 - loss: 0.1221 - val_accuracy: 0.9485 - val_loss: 0.1119
# Epoch 75/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 235ms/step - accuracy: 0.9398 - loss: 0.1670 - val_accuracy: 0.9519 - val_loss: 0.1082
# Epoch 76/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 234ms/step - accuracy: 0.9420 - loss: 0.1671 - val_accuracy: 0.9450 - val_loss: 0.1124
# Epoch 77/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 237ms/step - accuracy: 0.9511 - loss: 0.1591 - val_accuracy: 0.9553 - val_loss: 0.1070
# Epoch 78/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 239ms/step - accuracy: 0.9357 - loss: 0.1828 - val_accuracy: 0.9519 - val_loss: 0.1026
# Epoch 79/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 236ms/step - accuracy: 0.9524 - loss: 0.1328 - val_accuracy: 0.9519 - val_loss: 0.1178
# Epoch 80/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 236ms/step - accuracy: 0.9507 - loss: 0.1641 - val_accuracy: 0.9485 - val_loss: 0.1238
# Epoch 81/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 239ms/step - accuracy: 0.9503 - loss: 0.1220 - val_accuracy: 0.9485 - val_loss: 0.1206
# Epoch 82/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.9438 - loss: 0.1358 - val_accuracy: 0.9519 - val_loss: 0.1114
# Epoch 83/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 270ms/step - accuracy: 0.9575 - loss: 0.1205 - val_accuracy: 0.9622 - val_loss: 0.0998
# Epoch 84/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 234ms/step - accuracy: 0.9554 - loss: 0.1201 - val_accuracy: 0.9622 - val_loss: 0.0970
# Epoch 85/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 235ms/step - accuracy: 0.9470 - loss: 0.1368 - val_accuracy: 0.9622 - val_loss: 0.0974
# Epoch 86/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 237ms/step - accuracy: 0.9580 - loss: 0.1156 - val_accuracy: 0.9656 - val_loss: 0.0952
# Epoch 87/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 236ms/step - accuracy: 0.9589 - loss: 0.1247 - val_accuracy: 0.9588 - val_loss: 0.0938
# Epoch 88/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 235ms/step - accuracy: 0.9571 - loss: 0.1137 - val_accuracy: 0.9622 - val_loss: 0.0947
# Epoch 89/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 232ms/step - accuracy: 0.9501 - loss: 0.1454 - val_accuracy: 0.9519 - val_loss: 0.1107
# Epoch 90/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 234ms/step - accuracy: 0.9608 - loss: 0.1154 - val_accuracy: 0.9588 - val_loss: 0.0974
# Epoch 91/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 235ms/step - accuracy: 0.9663 - loss: 0.1024 - val_accuracy: 0.9622 - val_loss: 0.0912
# Epoch 92/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 234ms/step - accuracy: 0.9500 - loss: 0.1207 - val_accuracy: 0.9519 - val_loss: 0.1257
# Epoch 93/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 234ms/step - accuracy: 0.9452 - loss: 0.1288 - val_accuracy: 0.9519 - val_loss: 0.1299
# Epoch 94/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 238ms/step - accuracy: 0.9561 - loss: 0.1125 - val_accuracy: 0.9416 - val_loss: 0.1485
# Epoch 95/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 246ms/step - accuracy: 0.9417 - loss: 0.1548 - val_accuracy: 0.9553 - val_loss: 0.0989
# Epoch 96/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 237ms/step - accuracy: 0.9620 - loss: 0.1127 - val_accuracy: 0.9519 - val_loss: 0.1040
# Epoch 97/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 237ms/step - accuracy: 0.9560 - loss: 0.1023 - val_accuracy: 0.9553 - val_loss: 0.1009
# Epoch 98/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 237ms/step - accuracy: 0.9807 - loss: 0.0782 - val_accuracy: 0.9588 - val_loss: 0.0960
# Epoch 99/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 235ms/step - accuracy: 0.9673 - loss: 0.1105 - val_accuracy: 0.9588 - val_loss: 0.0898
# Epoch 100/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 239ms/step - accuracy: 0.9594 - loss: 0.1001 - val_accuracy: 0.9725 - val_loss: 0.0717
# Epoch 101/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 240ms/step - accuracy: 0.9619 - loss: 0.0892 - val_accuracy: 0.9691 - val_loss: 0.0691
# Epoch 102/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 238ms/step - accuracy: 0.9761 - loss: 0.0688 - val_accuracy: 0.9725 - val_loss: 0.0711
# Epoch 103/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 254ms/step - accuracy: 0.9794 - loss: 0.0685 - val_accuracy: 0.9691 - val_loss: 0.0858
# Epoch 104/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 241ms/step - accuracy: 0.9715 - loss: 0.0894 - val_accuracy: 0.9691 - val_loss: 0.0947
# Epoch 105/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 233ms/step - accuracy: 0.9677 - loss: 0.0837 - val_accuracy: 0.9725 - val_loss: 0.0895
# Epoch 106/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 233ms/step - accuracy: 0.9598 - loss: 0.0913 - val_accuracy: 0.9725 - val_loss: 0.0894
# Epoch 107/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 233ms/step - accuracy: 0.9698 - loss: 0.0737 - val_accuracy: 0.9691 - val_loss: 0.0903
# Epoch 108/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 253ms/step - accuracy: 0.9698 - loss: 0.0843 - val_accuracy: 0.9691 - val_loss: 0.0945
# Epoch 109/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 236ms/step - accuracy: 0.9690 - loss: 0.1048 - val_accuracy: 0.9622 - val_loss: 0.1140
# Epoch 110/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 235ms/step - accuracy: 0.9601 - loss: 0.0935 - val_accuracy: 0.9622 - val_loss: 0.1115
# Epoch 111/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 233ms/step - accuracy: 0.9731 - loss: 0.0906 - val_accuracy: 0.9622 - val_loss: 0.1056
# Epoch 112/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 270ms/step - accuracy: 0.9598 - loss: 0.0801 - val_accuracy: 0.9725 - val_loss: 0.0894
# Epoch 113/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 241ms/step - accuracy: 0.9702 - loss: 0.0724 - val_accuracy: 0.9759 - val_loss: 0.0857
# Epoch 114/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 240ms/step - accuracy: 0.9767 - loss: 0.0671 - val_accuracy: 0.9691 - val_loss: 0.0899
# Epoch 115/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 245ms/step - accuracy: 0.9727 - loss: 0.0873 - val_accuracy: 0.9691 - val_loss: 0.0869
# Epoch 116/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 244ms/step - accuracy: 0.9697 - loss: 0.0973 - val_accuracy: 0.9691 - val_loss: 0.0884
# Epoch 117/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 247ms/step - accuracy: 0.9681 - loss: 0.0760 - val_accuracy: 0.9656 - val_loss: 0.0943
# Epoch 118/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 250ms/step - accuracy: 0.9774 - loss: 0.0769 - val_accuracy: 0.9656 - val_loss: 0.1020
# Epoch 119/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 258ms/step - accuracy: 0.9766 - loss: 0.0637 - val_accuracy: 0.9691 - val_loss: 0.0994
# Epoch 120/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 243ms/step - accuracy: 0.9727 - loss: 0.0990 - val_accuracy: 0.9691 - val_loss: 0.0914
# Epoch 121/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 247ms/step - accuracy: 0.9757 - loss: 0.0579 - val_accuracy: 0.9725 - val_loss: 0.0809
# Epoch 122/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 238ms/step - accuracy: 0.9671 - loss: 0.0796 - val_accuracy: 0.9725 - val_loss: 0.0857
# Epoch 123/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 239ms/step - accuracy: 0.9704 - loss: 0.0820 - val_accuracy: 0.9725 - val_loss: 0.0818
# Epoch 124/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 237ms/step - accuracy: 0.9759 - loss: 0.0716 - val_accuracy: 0.9759 - val_loss: 0.0727
# Epoch 125/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 239ms/step - accuracy: 0.9777 - loss: 0.0769 - val_accuracy: 0.9759 - val_loss: 0.0727
# Epoch 126/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 262ms/step - accuracy: 0.9776 - loss: 0.0693 - val_accuracy: 0.9691 - val_loss: 0.0829
# Epoch 127/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 289ms/step - accuracy: 0.9684 - loss: 0.0755 - val_accuracy: 0.9725 - val_loss: 0.1003
# Epoch 128/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 287ms/step - accuracy: 0.9786 - loss: 0.0635 - val_accuracy: 0.9691 - val_loss: 0.0967
# Epoch 129/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 260ms/step - accuracy: 0.9712 - loss: 0.0645 - val_accuracy: 0.9725 - val_loss: 0.0879
# Epoch 130/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 254ms/step - accuracy: 0.9721 - loss: 0.0916 - val_accuracy: 0.9725 - val_loss: 0.0788
# Epoch 131/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 282ms/step - accuracy: 0.9735 - loss: 0.0686 - val_accuracy: 0.9725 - val_loss: 0.0856
# Epoch 132/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 243ms/step - accuracy: 0.9810 - loss: 0.0641 - val_accuracy: 0.9725 - val_loss: 0.0890
# Epoch 133/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 242ms/step - accuracy: 0.9658 - loss: 0.0822 - val_accuracy: 0.9725 - val_loss: 0.0944
# Epoch 134/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 238ms/step - accuracy: 0.9764 - loss: 0.0893 - val_accuracy: 0.9691 - val_loss: 0.0866
# Epoch 135/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 244ms/step - accuracy: 0.9798 - loss: 0.0752 - val_accuracy: 0.9725 - val_loss: 0.0789
# Epoch 136/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 247ms/step - accuracy: 0.9743 - loss: 0.0583 - val_accuracy: 0.9725 - val_loss: 0.0825
# Epoch 137/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 245ms/step - accuracy: 0.9759 - loss: 0.0673 - val_accuracy: 0.9725 - val_loss: 0.0901
# Epoch 138/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 245ms/step - accuracy: 0.9658 - loss: 0.0838 - val_accuracy: 0.9759 - val_loss: 0.0864
# Epoch 139/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 254ms/step - accuracy: 0.9812 - loss: 0.0688 - val_accuracy: 0.9725 - val_loss: 0.0888
# Epoch 140/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 255ms/step - accuracy: 0.9735 - loss: 0.0672 - val_accuracy: 0.9725 - val_loss: 0.0840
# Epoch 141/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 305ms/step - accuracy: 0.9813 - loss: 0.0587 - val_accuracy: 0.9725 - val_loss: 0.0692
# Epoch 142/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 287ms/step - accuracy: 0.9832 - loss: 0.0503 - val_accuracy: 0.9759 - val_loss: 0.0709
# Epoch 143/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 256ms/step - accuracy: 0.9874 - loss: 0.0394 - val_accuracy: 0.9759 - val_loss: 0.0776
# Epoch 144/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - accuracy: 0.9801 - loss: 0.0486 - val_accuracy: 0.9759 - val_loss: 0.0655
# Epoch 145/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 265ms/step - accuracy: 0.9780 - loss: 0.0641 - val_accuracy: 0.9759 - val_loss: 0.0619
# Epoch 146/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 271ms/step - accuracy: 0.9864 - loss: 0.0431 - val_accuracy: 0.9759 - val_loss: 0.0689
# Epoch 147/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 250ms/step - accuracy: 0.9758 - loss: 0.0536 - val_accuracy: 0.9759 - val_loss: 0.0763
# Epoch 148/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 257ms/step - accuracy: 0.9719 - loss: 0.0581 - val_accuracy: 0.9759 - val_loss: 0.0709
# Epoch 149/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.9769 - loss: 0.0637 - val_accuracy: 0.9759 - val_loss: 0.0753
# Epoch 150/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 255ms/step - accuracy: 0.9857 - loss: 0.0339 - val_accuracy: 0.9828 - val_loss: 0.0421
# Epoch 151/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 246ms/step - accuracy: 0.9855 - loss: 0.0379 - val_accuracy: 0.9794 - val_loss: 0.0373
# Epoch 152/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 260ms/step - accuracy: 0.9819 - loss: 0.0433 - val_accuracy: 0.9828 - val_loss: 0.0526
# Epoch 153/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 275ms/step - accuracy: 0.9821 - loss: 0.0654 - val_accuracy: 0.9794 - val_loss: 0.0635
# Epoch 154/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 245ms/step - accuracy: 0.9899 - loss: 0.0286 - val_accuracy: 0.9794 - val_loss: 0.0678
# Epoch 155/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 254ms/step - accuracy: 0.9796 - loss: 0.0536 - val_accuracy: 0.9725 - val_loss: 0.0824
# Epoch 156/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 245ms/step - accuracy: 0.9769 - loss: 0.0605 - val_accuracy: 0.9794 - val_loss: 0.0675
# Epoch 157/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 247ms/step - accuracy: 0.9846 - loss: 0.0566 - val_accuracy: 0.9794 - val_loss: 0.0641
# Epoch 158/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 246ms/step - accuracy: 0.9777 - loss: 0.0613 - val_accuracy: 0.9794 - val_loss: 0.0624
# Epoch 159/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - accuracy: 0.9806 - loss: 0.0559 - val_accuracy: 0.9759 - val_loss: 0.0691
# Epoch 160/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - accuracy: 0.9795 - loss: 0.0538 - val_accuracy: 0.9794 - val_loss: 0.0703
# Epoch 161/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - accuracy: 0.9880 - loss: 0.0378 - val_accuracy: 0.9794 - val_loss: 0.0694
# Epoch 162/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 253ms/step - accuracy: 0.9843 - loss: 0.0512 - val_accuracy: 0.9794 - val_loss: 0.0660
# Epoch 163/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 245ms/step - accuracy: 0.9871 - loss: 0.0348 - val_accuracy: 0.9794 - val_loss: 0.0671
# Epoch 164/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 251ms/step - accuracy: 0.9792 - loss: 0.0521 - val_accuracy: 0.9794 - val_loss: 0.0654
# Epoch 165/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 274ms/step - accuracy: 0.9848 - loss: 0.0420 - val_accuracy: 0.9794 - val_loss: 0.0618
# Epoch 166/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 250ms/step - accuracy: 0.9858 - loss: 0.0380 - val_accuracy: 0.9794 - val_loss: 0.0628
# Epoch 167/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 246ms/step - accuracy: 0.9810 - loss: 0.0525 - val_accuracy: 0.9759 - val_loss: 0.0678
# Epoch 168/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 274ms/step - accuracy: 0.9887 - loss: 0.0328 - val_accuracy: 0.9794 - val_loss: 0.0638
# Epoch 169/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 247ms/step - accuracy: 0.9739 - loss: 0.0736 - val_accuracy: 0.9794 - val_loss: 0.0525
# Epoch 170/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 254ms/step - accuracy: 0.9808 - loss: 0.0465 - val_accuracy: 0.9725 - val_loss: 0.0582
# Epoch 171/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 272ms/step - accuracy: 0.9703 - loss: 0.0836 - val_accuracy: 0.9897 - val_loss: 0.0371
# Epoch 172/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - accuracy: 0.9682 - loss: 0.1015 - val_accuracy: 0.9828 - val_loss: 0.0436
# Epoch 173/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 246ms/step - accuracy: 0.9805 - loss: 0.0631 - val_accuracy: 0.9863 - val_loss: 0.0391
# Epoch 174/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 246ms/step - accuracy: 0.9707 - loss: 0.0854 - val_accuracy: 0.9863 - val_loss: 0.0293
# Epoch 175/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 245ms/step - accuracy: 0.9756 - loss: 0.0655 - val_accuracy: 0.9897 - val_loss: 0.0277
# Epoch 176/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 247ms/step - accuracy: 0.9825 - loss: 0.0430 - val_accuracy: 0.9828 - val_loss: 0.0373
# Epoch 177/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - accuracy: 0.9793 - loss: 0.0527 - val_accuracy: 0.9794 - val_loss: 0.0419
# Epoch 178/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.9804 - loss: 0.0530 - val_accuracy: 0.9828 - val_loss: 0.0328
# Epoch 179/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.9882 - loss: 0.0364 - val_accuracy: 0.9897 - val_loss: 0.0274
# Epoch 180/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.9819 - loss: 0.0466 - val_accuracy: 0.9725 - val_loss: 0.0790
# Epoch 181/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - accuracy: 0.9655 - loss: 0.0773 - val_accuracy: 0.9691 - val_loss: 0.0730
# Epoch 182/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 245ms/step - accuracy: 0.9879 - loss: 0.0436 - val_accuracy: 0.9794 - val_loss: 0.0599
# Epoch 183/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 276ms/step - accuracy: 0.9675 - loss: 0.1495 - val_accuracy: 0.9794 - val_loss: 0.0782
# Epoch 184/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 247ms/step - accuracy: 0.9733 - loss: 0.0733 - val_accuracy: 0.9828 - val_loss: 0.0361
# Epoch 185/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 247ms/step - accuracy: 0.9788 - loss: 0.0576 - val_accuracy: 0.9931 - val_loss: 0.0207
# Epoch 186/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.9818 - loss: 0.0493 - val_accuracy: 0.9931 - val_loss: 0.0169
# Epoch 187/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 244ms/step - accuracy: 0.9938 - loss: 0.0307 - val_accuracy: 0.9931 - val_loss: 0.0171
# Epoch 188/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - accuracy: 0.9904 - loss: 0.0337 - val_accuracy: 0.9897 - val_loss: 0.0206
# Epoch 189/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 252ms/step - accuracy: 0.9880 - loss: 0.0418 - val_accuracy: 0.9897 - val_loss: 0.0249
# Epoch 190/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 272ms/step - accuracy: 0.9797 - loss: 0.0515 - val_accuracy: 0.9863 - val_loss: 0.0482
# Epoch 191/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 247ms/step - accuracy: 0.9890 - loss: 0.0401 - val_accuracy: 0.9897 - val_loss: 0.0385
# Epoch 192/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 251ms/step - accuracy: 0.9805 - loss: 0.0598 - val_accuracy: 0.9794 - val_loss: 0.0446
# Epoch 193/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.9832 - loss: 0.0636 - val_accuracy: 0.9828 - val_loss: 0.0479
# Epoch 194/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.9870 - loss: 0.0417 - val_accuracy: 0.9828 - val_loss: 0.0451
# Epoch 195/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 251ms/step - accuracy: 0.9888 - loss: 0.0340 - val_accuracy: 0.9897 - val_loss: 0.0260
# Epoch 196/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 246ms/step - accuracy: 0.9898 - loss: 0.0347 - val_accuracy: 0.9931 - val_loss: 0.0189
# Epoch 197/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 275ms/step - accuracy: 0.9871 - loss: 0.0427 - val_accuracy: 0.9897 - val_loss: 0.0223
# Epoch 198/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 249ms/step - accuracy: 0.9836 - loss: 0.0475 - val_accuracy: 0.9863 - val_loss: 0.0253
# Epoch 199/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 248ms/step - accuracy: 0.9920 - loss: 0.0277 - val_accuracy: 0.9863 - val_loss: 0.0297
# Epoch 200/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 250ms/step - accuracy: 0.9864 - loss: 0.0432 - val_accuracy: 0.9863 - val_loss: 0.0252

# %%
figure = plt.figure(figsize=(10, 10))
plt.plot(hist.history['accuracy'], label='Train_accuracy')
plt.plot(hist.history['val_accuracy'], label='Test_accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc="upper left")
plt.show()

figure2 = plt.figure(figsize=(10, 10))
plt.plot(hist.history['loss'], label='Train_loss')
plt.plot(hist.history['val_loss'], label='Test_loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="upper left")
plt.show()

# %%
pred = model.evaluate(X_test, Y_test)
print(f'Test Set Accuracy: {pred[1]}')
print(f'Test Set Loss: {pred[0]}')
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9888 - loss: 0.0211
# Test Set Accuracy: 0.9862542748451233
# Test Set Loss: 0.025206321850419044

# %%
ypred = model.predict(X_test)
ypred = np.argmax(ypred, axis=1)
Y_test_pred = np.argmax(Y_test, axis=1)
print(classification_report(Y_test_pred, ypred))
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99       159
#            1       0.97      1.00      0.99       132
#
#     accuracy                           0.99       291
#    macro avg       0.99      0.99      0.99       291
# weighted avg       0.99      0.99      0.99       291

# %%
matrix = confusion_matrix(Y_test_pred, ypred)
df_cm = pd.DataFrame(matrix, index=[0,1], columns=[0,1])
figure = plt.figure(figsize=(5,5))
sns.heatmap(df_cm, annot=True, fmt='d')
# Out:
# <Axes: >

# %%
model.save('Driver_Drowsiness_Detection.keras')

# %%
labels = ['Closed', 'Open']
img_closed1 = cv2.imread(r"C:\Users\dell\Downloads\driver_drowsiness_detection_modified\driver_drowsiness_detection\closed_eye.jpg")
img_closed2 = cv2.imread(r"C:\Users\dell\Downloads\driver_drowsiness_detection_modified\driver_drowsiness_detection\closed_eye2.jpg")
img_open1 = cv2.imread(r"C:\Users\dell\Downloads\driver_drowsiness_detection_modified\driver_drowsiness_detection\open_eye.jpg")
img_open2 = cv2.imread(r"C:\Users\dell\Downloads\driver_drowsiness_detection_modified\driver_drowsiness_detection\open_eye.jpg")

img_closed1 = cv2.resize(img_closed1, (32, 32))
img_closed2 = cv2.resize(img_closed2, (32, 32))
img_open1 = cv2.resize(img_open1, (32, 32))
img_open2 = cv2.resize(img_open2, (32, 32))

img_closed1 = np.array(img_closed1)
img_closed2 = np.array(img_closed2)
img_open1 = np.array(img_open1)
img_open2 = np.array(img_open2)

img_closed1 = np.expand_dims(img_closed1, axis=0)
img_closed2 = np.expand_dims(img_closed2, axis=0)
img_open1 = np.expand_dims(img_open1, axis=0)
img_open2 = np.expand_dims(img_open2, axis=0)

# %%
ypred_closed1 = model.predict(img_closed1)
ypred_closed2 = model.predict(img_closed2)
ypred_open1 = model.predict(img_open1)
ypred_open2 = model.predict(img_open2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 745ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step

# %%
figure = plt.figure(figsize=(2, 2))
img_closed1 = np.squeeze(img_closed1, axis=0)
plt.imshow(img_closed1)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_closed1[0], axis=0)]}')
plt.show()

# %%
figure = plt.figure(figsize=(2, 2))
img_closed2 = np.squeeze(img_closed2, axis=0)
plt.imshow(img_closed2)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_closed2[0], axis=0)]}')
plt.show()

# %%
figure = plt.figure(figsize=(2, 2))
img_open1 = np.squeeze(img_open1, axis=0)
plt.imshow(img_open1)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_open1[0], axis=0)]}')
plt.show()

# %%
figure = plt.figure(figsize=(2, 2))
img_open2 = np.squeeze(img_open2, axis=0)
plt.imshow(img_open2)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_open2[0], axis=0)]}')
plt.show()

# %%
def full_face_detection_pipeline(input_image_path):
    face_cascade = cv2.CascadeClassifier('driver_drowsiness_detection/haarcascade_frontalface_default.xml')
    eye_cascade = cv2.CascadeClassifier('driver_drowsiness_detection/haarcascade_eye.xml')
    detector = dlib.get_frontal_face_detector()
    predictor = dlib.shape_predictor('driver_drowsiness_detection/shape_predictor_68_face_landmarks.dat')
    fa = FaceAligner(predictor, desiredFaceWidth=256)
    test_image = cv2.imread(input_image_path)
    test_image = imutils.resize(test_image, width=800)
    test_image_gray = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)
    rects = detector(test_image_gray, 2)
    for rect in rects:
        (x, y, w, h) = rect_to_bb(rect)
        faceOrig = imutils.resize(test_image[y:y+h, x:x+w], width=256)
        faceAligned = fa.align(test_image, test_image_gray, rect)
        faceAligned_gray = cv2.cvtColor(faceAligned, cv2.COLOR_BGR2GRAY)
        plt.imshow(faceAligned_gray)
        plt.axis('off')
        plt.title('Aligned Face')
        plt.show()
        eyes = eye_cascade.detectMultiScale(faceAligned_gray, 1.1, 4)
        predictions = []
        for (ex, ey, ew, eh) in eyes:
            eye = faceAligned[ey:ey+eh, ex:ex+ew]
#             cv2.rectangle(test_image, (x+ex, y+ey), (x+ex+ew, y+ey+eh), (0, 0, 255), 8)
            eye = cv2.resize(eye, (32, 32))
            eye = np.array(eye)
            eye = np.expand_dims(eye, axis=0)
            ypred = model.predict(eye)
            ypred = np.argmax(ypred[0], axis=0)
            predictions.append(ypred)
        if all(i==0 for i in predictions):
            cv2.rectangle(test_image, (x, y), (x+w, y+h), (0, 0, 255), 8)
            cv2.putText(test_image, 'Sleeping', (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0, 0, 255), 3)
        else:
            cv2.rectangle(test_image, (x, y), (x+w, y+h), (0, 255, 0), 8)
            cv2.putText(test_image, 'Not Sleeping', (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0, 255, 0), 3)
    output_path = 'driver_drowsiness_detection/test_image_prediction.jpg'
    cv2.imwrite(output_path, test_image) 
    return output_path

# %%
figure = plt.figure(figsize=(5, 5))
predicted_image = cv2.imread(full_face_detection_pipeline('driver_drowsiness_detection/active_person.jpg'))
predicted_image = cv2.cvtColor(predicted_image, cv2.COLOR_BGR2RGB)
plt.imshow(predicted_image)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 2
#       1 figure = plt.figure(figsize=(5, 5))
# ----> 2 predicted_image = cv2.imread(full_face_detection_pipeline('driver_drowsiness_detection/active_person.jpg'))
#       3 predicted_image = cv2.cvtColor(predicted_image, cv2.COLOR_BGR2RGB)
#       4 plt.imshow(predicted_image)
#
# Cell In[47], line 4, in full_face_detection_pipeline(input_image_path)
#       2 face_cascade = cv2.CascadeClassifier('driver_drowsiness_detection/haarcascade_frontalface_default.xml')
#       3 eye_cascade = cv2.CascadeClassifier('driver_drowsiness_detection/haarcascade_eye.xml')
# ----> 4 detector = dlib.get_frontal_face_detector()
#       5 predictor = dlib.shape_predictor('driver_drowsiness_detection/shape_predictor_68_face_landmarks.dat')
#       6 fa = FaceAligner(predictor, desiredFaceWidth=256)
#
# NameError: name 'dlib' is not defined

# %%
import pandas as pd

# %%
import numpy as np

# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import tensorflow as tf
#
# File ~\Desktop\Personal Projects - Application of Data Science\Personal-Projects---Data-Science\TensorFlow\Projects\.venv\Lib\site-packages\tensorflow\__init__.py:45
#      42 from tensorflow.python import tf2 as _tf2
#      43 _tf2.enable()
# ---> 45 from tensorflow._api.v2 import __internal__
#      46 from tensorflow._api.v2 import __operators__
#      47 from tensorflow._api.v2 import audio
#
# File ~\Desktop\Personal Projects - Application of Data Science\Personal-Projects---Data-Science\TensorFlow\Projects\.venv\Lib\site-packages\tensorflow\_api\v2\__internal__\__init__.py:8
#       3 """Public API for tf._api.v2.__internal__ namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.__internal__ import autograph
# ...
